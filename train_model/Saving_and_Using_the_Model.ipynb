# %%
import tensorflow as tf
tf.__version__
# Out:
# 2023-01-25 19:09:44.017389: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# '2.9.1'

# %% [markdown]
# ## Training and Saving the Selected Model

# %%
from tensorflow import keras

from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input
from tensorflow.keras.applications.mobilenet import decode_predictions

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# specify the paths to the data directories
train_dir = "data/train"
val_dir = "data/validation"
test_dir = "data/test"

# %%
# Function to create model

def make_model(learning_rate=0.01):
    base_model = MobileNet(weights='imagenet',
                          include_top=False,
                          input_shape=(224,224,3))

    base_model.trainable = False
    
    #########################################
    
    inputs = keras.Input(shape=(224,224, 3))
    base = base_model(inputs, training=False)
    vectors = keras.layers.GlobalAveragePooling2D()(base)
    outputs = keras.layers.Dense(3)(vectors)
    model = keras.Model(inputs, outputs)
    
    #########################################
    
    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    loss = keras.losses.CategoricalCrossentropy(from_logits=True)

    # Compile the model
    model.compile(optimizer=optimizer,
                  loss=loss,
                  metrics=['accuracy'])
    
    return model

# %%
# Training with Data Augmentation

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range = 30,
    width_shift_range = 10.0,
    height_shift_range=10.0,
    zoom_range=0.1,
    vertical_flip=True
)

train_ds = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32
)

val_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

val_ds = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    shuffle=False
)

test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_ds = val_gen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    shuffle=False
)
# Out:
# Found 928 images belonging to 3 classes.
# Found 115 images belonging to 3 classes.
# Found 115 images belonging to 3 classes.

# %%
checkpoint = keras.callbacks.ModelCheckpoint(
    'mobilenet_v1_{epoch:02d}_{val_accuracy:.3f}.h5',
    save_best_only=True,
    monitor='val_accuracy',
    mode='max'
)

# %%
learning_rate = 0.01

model = make_model(learning_rate=learning_rate)

history = model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds,
    callbacks=[checkpoint]
)
# Out:
# 2023-01-25 19:09:45.835481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:45.842201: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:45.842541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:45.843047: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-25 19:09:45.843419: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:45.843721: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:45.843973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:46.458596: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:46.458934: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:46.459195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-25 19:09:46.459425: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 51 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:1e.0, compute capability: 7.5
# Epoch 1/10
# 2023-01-25 19:09:59.306193: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 18.38MiB (rounded to 19267584)requested by op model/mobilenet_1.00_224/conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-01-25 19:09:59.306253: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2023-01-25 19:09:59.306265: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 78, Chunks in use: 76. 19.5KiB allocated for chunks. 19.0KiB in use in bin. 3.5KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306273: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 17, Chunks in use: 17. 8.8KiB allocated for chunks. 8.8KiB in use in bin. 8.4KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306282: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 18, Chunks in use: 18. 19.5KiB allocated for chunks. 19.5KiB in use in bin. 18.1KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306291: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 50, Chunks in use: 50. 102.8KiB allocated for chunks. 102.8KiB in use in bin. 101.6KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306299: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 14, Chunks in use: 14. 59.0KiB allocated for chunks. 59.0KiB in use in bin. 57.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306307: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 7, Chunks in use: 6. 73.0KiB allocated for chunks. 63.0KiB in use in bin. 62.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306314: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 5, Chunks in use: 5. 102.8KiB allocated for chunks. 102.8KiB in use in bin. 90.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306322: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 100.0KiB allocated for chunks. 100.0KiB in use in bin. 86.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306330: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 2, Chunks in use: 1. 131.8KiB allocated for chunks. 64.0KiB in use in bin. 64.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306338: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 2, Chunks in use: 1. 263.5KiB allocated for chunks. 128.0KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306347: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 2, Chunks in use: 1. 724.0KiB allocated for chunks. 256.0KiB in use in bin. 256.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306359: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 2, Chunks in use: 1. 1.25MiB allocated for chunks. 512.0KiB in use in bin. 512.0KiB client-requested in use in bin.
# 2023-01-25 19:09:59.306369: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 5, Chunks in use: 5. 5.50MiB allocated for chunks. 5.50MiB in use in bin. 5.00MiB client-requested in use in bin.
# 2023-01-25 19:09:59.306379: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 1, Chunks in use: 1. 3.00MiB allocated for chunks. 3.00MiB in use in bin. 2.00MiB client-requested in use in bin.
# 2023-01-25 19:09:59.306388: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 1, Chunks in use: 1. 4.00MiB allocated for chunks. 4.00MiB in use in bin. 4.00MiB client-requested in use in bin.
# 2023-01-25 19:09:59.306398: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-25 19:09:59.306418: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-25 19:09:59.306429: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 1, Chunks in use: 1. 36.43MiB allocated for chunks. 36.43MiB in use in bin. 18.38MiB client-requested in use in bin.
# 2023-01-25 19:09:59.306441: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-25 19:09:59.306450: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-25 19:09:59.306460: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-25 19:09:59.306471: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for 18.38MiB was 16.00MiB, Chunk State:
# 2023-01-25 19:09:59.306479: I tensorflow/core/common_runtime/bfc_allocator.cc:1063] Next region of size 54263808
# 2023-01-25 19:09:59.306495: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000000 of size 1280 next 1
# 2023-01-25 19:09:59.306504: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000500 of size 256 next 2
# 2023-01-25 19:09:59.306512: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000600 of size 256 next 3
# 2023-01-25 19:09:59.306521: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000700 of size 256 next 4
# 2023-01-25 19:09:59.306529: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000800 of size 256 next 5
# 2023-01-25 19:09:59.306538: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000900 of size 256 next 8
# 2023-01-25 19:09:59.306547: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000a00 of size 256 next 9
# 2023-01-25 19:09:59.306555: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000b00 of size 256 next 10
# 2023-01-25 19:09:59.306563: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000c00 of size 256 next 11
# 2023-01-25 19:09:59.306572: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000d00 of size 256 next 12
# 2023-01-25 19:09:59.306580: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000e00 of size 256 next 13
# 2023-01-25 19:09:59.306588: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48000f00 of size 256 next 20
# 2023-01-25 19:09:59.306597: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48001000 of size 256 next 21
# 2023-01-25 19:09:59.306605: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48001100 of size 256 next 24
# 2023-01-25 19:09:59.306613: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48001200 of size 256 next 25
# 2023-01-25 19:09:59.306621: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48001300 of size 256 next 26
# 2023-01-25 19:09:59.306630: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efd48
I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 16 Chunks of size 512 totalling 8.0KiB
# 2023-01-25 19:09:59.308660: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 768 totalling 768B
# 2023-01-25 19:09:59.308671: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 14 Chunks of size 1024 totalling 14.0KiB
# 2023-01-25 19:09:59.308683: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 1280 totalling 3.8KiB
# 2023-01-25 19:09:59.308697: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1792 totalling 1.8KiB
# 2023-01-25 19:09:59.308707: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 46 Chunks of size 2048 totalling 92.0KiB
# 2023-01-25 19:09:59.308718: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 2304 totalling 4.5KiB
# 2023-01-25 19:09:59.308729: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 2816 totalling 2.8KiB
# 2023-01-25 19:09:59.308744: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 3584 totalling 3.5KiB
# 2023-01-25 19:09:59.308755: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 11 Chunks of size 4096 totalling 44.0KiB
# 2023-01-25 19:09:59.308765: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 4608 totalling 4.5KiB
# 2023-01-25 19:09:59.308771: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 5120 totalling 5.0KiB
# 2023-01-25 19:09:59.308778: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 5632 totalling 5.5KiB
# 2023-01-25 19:09:59.308787: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 8192 totalling 8.0KiB
# 2023-01-25 19:09:59.308795: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 9216 totalling 9.0KiB
# 2023-01-25 19:09:59.308802: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 10240 totalling 10.0KiB
# 2023-01-25 19:09:59.308809: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 12288 totalling 36.0KiB
# 2023-01-25 19:09:59.308819: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 4 Chunks of size 18432 totalling 72.0KiB
# 2023-01-25 19:09:59.308829: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 31488 totalling 30.8KiB
# 2023-01-25 19:09:59.308839: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 32768 totalling 64.0KiB
# 2023-01-25 19:09:59.308846: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 36864 totalling 36.0KiB
# 2023-01-25 19:09:59.308852: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 65536 totalling 64.0KiB
# 2023-01-25 19:09:59.308859: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 131072 totalling 128.0KiB
# 2023-01-25 19:09:59.308866: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 262144 totalling 256.0KiB
# 2023-01-25 19:09:59.308872: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 524288 totalling 512.0KiB
# 2023-01-25 19:09:59.308879: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 4 Chunks of size 1048576 totalling 4.00MiB
# 2023-01-25 19:09:59.308885: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1572864 totalling 1.50MiB
# 2023-01-25 19:09:59.308891: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 3145728 totalling 3.00MiB
# 2023-01-25 19:09:59.308901: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 4194304 totalling 4.00MiB
# 2023-01-25 19:09:59.308912: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 38202880 totalling 36.43MiB
# 2023-01-25 19:09:59.308919: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 50.33MiB
# 2023-01-25 19:09:59.308925: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 54263808 memory_limit_: 54263808 available bytes: 0 curr_region_allocation_bytes_: 108527616
# 2023-01-25 19:09:59.308938: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                        54263808
# InUse:                        52779264
# MaxInUse:                     52779520
# NumAllocs:                         424
# MaxAllocSize:                 38202880
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-01-25 19:09:59.308958: W tensorflow/core/common_runtime/bfc_allocator.cc:491] ********************x*********************************************xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 2023-01-25 19:09:59.309011: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at transpose_op.cc:183 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,3,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In [7], line 5
#       1 learning_rate = 0.01
#       3 model = make_model(learning_rate=learning_rate)
# ----> 5 history = model.fit(
#       6     train_ds,
#       7     epochs=10,
#       8     validation_data=val_ds,
#       9     callbacks=[checkpoint]
#      10 )
#
# File /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /opt/saturncloud/envs/saturn/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[32,3,224,224] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model/mobilenet_1.00_224/conv1/Conv2D-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_4664]
