# %% [markdown]
# ## Preparing the train/validation/test image folders
#
# See below for the source and target data directory structures and number of files in each subfolder/category.
#
# There are 3 target subfolders: train, validation, test (data split will be 80/10/10). There are 3 categories of images: coast, forest, mountain.

# %% [markdown]
# ### Source sun09 dataset structure
# ```
# data_sun09
# |
# |- coast (405 images)
# |- forest (351 images)
# |- mountain (402 images)
# ```
#
# ### Data folder structure
#
# ```
# data
# |
# |-train
# |    |- coast (325 files)
# |    |- forest ( 281 files )
# |    |- mountain (322 files )
# |
# |-validation
# |    |- coast (40 files)
# |    |- forest (35 files )
# |    |- mountain (40 files )
# |
# |-test
# |    |- coast (40 files)
# |    |- forest (35 files )
# |    |- mountain (40 files )
# ```
#
# coast total files: 325+40+40 = 405
# forest total files: 281+35+35 = 351
# mountain total files: 322+40+40 = 402

# %%
import os
import shutil
import math

# %%
original_dataset_dir = "../data_sun09/"  # image file source directory
cnn_dataset_dir = "../data/"    # we are creating this directory with train, val, test subfolders

# %%
# Create the train, validation, test subfolders within data/

base_dir = cnn_dataset_dir

if not os.path.exists(base_dir):
    os.mkdir(base_dir)

train_dir = os.path.join(base_dir,'train')
if not os.path.exists(train_dir):
    os.mkdir(train_dir)
    
validation_dir = os.path.join(base_dir,'validation')
if not os.path.exists(validation_dir):
    os.mkdir(validation_dir)
    
test_dir = os.path.join(base_dir,'test')
if not os.path.exists(test_dir):
    os.mkdir(test_dir)

# %%
# !ls -R ../data
# Out:
# test       train      validation
#
# ../data/test:
#
# ../data/train:
#
# ../data/validation:

# %%
# Create the category directories within the train/test/validation split subfolders

if not os.path.exists(base_dir):
    os.mkdir(base_dir)

# create the category subdirs within the split folder
def create_splitdir(split_dir_name):
    
    split_dir = os.path.join(base_dir, split_dir_name)
    if not os.path.exists(split_dir):
        os.mkdir(split_dir)  
        
    split_coast_dir = os.path.join(split_dir,'coast')
    if not os.path.exists(split_coast_dir):
        os.mkdir(split_coast_dir)
        
    split_forest_dir = os.path.join(split_dir,'forest')
    if not os.path.exists(split_forest_dir):
        os.mkdir(split_forest_dir)
        
    split_mountain_dir = os.path.join(split_dir,'mountain')
    if not os.path.exists(split_mountain_dir):
        os.mkdir(split_mountain_dir)  

        
# create the train folder and its subfolders
create_splitdir("train")
# create the validation folder
create_splitdir("validation")
# create the test folder and its subfolders
create_splitdir("test")

# %%
# !ls -R ../data
# Out:
# test       train      validation
#
# ../data/test:
# coast    forest   mountain
#
# ../data/test/coast:
#
# ../data/test/forest:
#
# ../data/test/mountain:
#
# ../data/train:
# coast    forest   mountain
#
# ../data/train/coast:
#
# ../data/train/forest:
#
# ../data/train/mountain:
#
# ../data/validation:
# coast    forest   mountain
#
# ../data/validation/coast:
#
# ../data/validation/forest:
#
# ../data/validation/mountain:

# %% [markdown]
# ## Split each category and copy to respective subfolders
#
# The train/val/test split is 80/10/10.

# %%
def copy_files(category_name):

    # Get the list of file names in each category folder of the original dataset
    cat_fnames = os.listdir(os.path.join(original_dataset_dir, category_name))
    cat_fnames.sort()
    
    # Get the number of files in the category 
    print(f"Number of files in {category_name} dataset: {len(cat_fnames)}")
    print(*cat_fnames, sep="\n")

    # We'll do a 80-10-10 train-val-test split for each category
    val_test_size = round( 0.10*len(cat_fnames) )  # size of val and test set

    # Select fnames evenly from the sequence list of file names for 'coast' since files are named 'semantically'
    gap = math.floor( len(cat_fnames)/val_test_size )
    print(f"Gap: {gap}")

    # select file names for validation folder
    cat_val_fnames = [ cat_fnames[i*gap] for i in range( round( 0.10*len(cat_fnames) ))]
    print(f"Number of {category_name} files for validation: { len(cat_val_fnames) }")

    cat_test_fnames = [ cat_fnames[i*gap+1] for i in range( round( 0.10*len(cat_fnames) ))]
    print(f"Number of {category_name} files for test: { len(cat_test_fnames) }")

    # copy the coast files to their designated respetive subfolders 
          
          
    original_cat_dir = os.path.join(original_dataset_dir, category_name)
        
    # validation files
    validation_cat_dir = os.path.join(validation_dir, category_name)
    for fname in cat_val_fnames:
        src = os.path.join(original_cat_dir, fname)
        dst = os.path.join(validation_cat_dir, fname)
        shutil.copyfile(src, dst)
    print(f"Number of files in {category_name} validation: {len(os.listdir(validation_cat_dir))}" )

    # test files
    test_cat_dir = os.path.join(test_dir, category_name)
    for fname in cat_test_fnames:
        src = os.path.join(original_cat_dir, fname)
        dst = os.path.join(test_cat_dir, fname)
        shutil.copyfile(src, dst)
    print(f"Number of files in {category_name} test: {len(os.listdir(test_cat_dir))}" )
          
    # train files
    train_cat_dir = os.path.join(train_dir, category_name)
    for fname in cat_fnames:
        if fname in cat_test_fnames or fname in cat_val_fnames:
            pass
        else:
            src = os.path.join(original_cat_dir, fname)
            dst = os.path.join(train_cat_dir, fname)
            shutil.copyfile(src, dst)
    print(f"Number of files in {category_name} train: {len(os.listdir(train_cat_dir))}" )

# %%
# copy the coast files
copy_files("coast")
# Out:
# Number of files in coast dataset: 405
# b_beach_coast_bea1.jpg
# b_beach_coast_bea10.jpg
# b_beach_coast_bea14.jpg
# b_beach_coast_bea2.jpg
# b_beach_coast_bea26.jpg
# b_beach_coast_bea27.jpg
# b_beach_coast_bea29.jpg
# b_beach_coast_bea3.jpg
# b_beach_coast_bea38.jpg
# b_beach_coast_bea39.jpg
# b_beach_coast_bea4.jpg
# b_beach_coast_bea5.jpg
# b_beach_coast_bea9.jpg
# b_beach_coast_cdmc1000.jpg
# b_beach_coast_cdmc123.jpg
# b_beach_coast_cdmc821.jpg
# b_beach_coast_cdmc851.jpg
# b_beach_coast_cdmc862.jpg
# b_beach_coast_cdmc866.jpg
# b_beach_coast_cdmc871.jpg
# b_beach_coast_cdmc873.jpg
# b_beach_coast_cdmc906.jpg
# b_beach_coast_cdmc916.jpg
# b_beach_coast_cdmc922.jpg
# b_beach_coast_cdmc933.jpg
# b_beach_coast_cdmc934.jpg
# b_beach_coast_cdmc940.jpg
# b_beach_coast_cdmc942.jpg
# b_beach_coast_cdmc948.jpg
# b_beach_coast_cdmc954.jpg
# b_beach_coast_cdmc976.jpg
# b_beach_coast_cdmc977.jpg
# b_beach_coast_cdmc988.jpg
# b_beach_coast_cdmc997.jpg
# c_coast_coast_sun39.jpg
# c_coast_coast_sun4.jpg
# c_coast_coast_sun42.jpg
# c_coast_coast_sun44.jpg
# c_coast_coast_sun45.jpg
# c_coast_coast_sun5.jpg
# c_coast_coast_sun56.jpg
# c_coast_coast_sun8.jpg
# c_coast_corp2029.jpg
# c_coast_google_34_7_2_coast.jpg
# c_coast_google_9_5_3_coast.jpg
# c_coast_na006657.jpg
# c_coast_na007299.jpg
# c_coast_na008710.jpg
# c_coast_opencountry_cdmc937.jpg
# c_coast_opencountry_nat499.jpg
# c_coast_opencountry_nat599.jpg
# c_coast_opencountry_open61.jpg
# o_ocean_coast_arnat59.jpg
# o_ocean_coast_art1130.jpg
# o_ocean_coast_cdmc825.jpg
# o_ocean_coast_cdmc891.jpg
# o_ocean_coast_cdmc900.jpg
# o_ocean_coast_cdmc929.jpg
# o_ocean_coast_cdmc989.jpg
# o_ocean_coast_land100.jpg
# o_ocean_coast_land108.jpg
# o_ocean_coast_land111.jpg
# o_ocean_coast_land368.jpg
# o_ocean_coast_land371.jpg
# o_ocean_coast_land372.jpg
# o_ocean_coast_land924.jpg
# o_ocean_coast_n241018.jpg
# o_ocean_coast_n286045.jpg
# o_ocean_coast_n295080.jpg
# o_ocean_coast_n328052.jpg
# o_ocean_coast_n347047.jpg
# o_ocean_coast_n424023.jpg
# o_ocean_coast_n672000.jpg
# o_ocean_coast_n672021.jpg
# o_ocean_coast_n708050.jpg
# o_ocean_coast_nat1043.jpg
# o_ocean_coast_nat1053.jpg
# o_ocean_coast_nat1112.jpg
# o_ocean_coast_nat1175.jpg
# o_ocean_coast_nat1177.jpg
# o_ocean_coast_nat1201.jpg
# o_ocean_coast_nat167.jpg
# o_ocean_coast_nat196.jpg
# o_ocean_coast_nat202.jpg
# o_ocean_coast_nat285.jpg
# o_ocean_coast_nat288.jpg
# o_ocean_coast_nat294.jpg
# o_ocean_coast_nat482.jpg
# o_ocean_coast_nat643.jpg
# o_ocean_coast_nat684.jpg
# o_ocean_coast_nat711.jpg
# o_ocean_coast_nat743.jpg
# o_ocean_coast_nat810.jpg
# o_ocean_coast_nat893.jpg
# o_ocean_coast_nat897.jpg
# o_ocean_coast_nat899.jpg
# o_ocean_coast_nat900.jpg
# o_ocean_coast_nat901.jpg
# o_ocean_coast_nat904.jpg
# o_ocean_coast_nat907.jpg
# o_ocean_coast_natu128.jpg
# o_ocean_coast_natu643.jpg
# o_ocean_coast_natu648.jpg
# o_ocean_coast_natu649.jpg
# o_ocean_coast_natu824.jpg
# o_ocean_coast_natu826.jpg
# o_ocean_coast_natu986.jpg
# o_ocean_coast_sun1.jpg
# o_ocean_coast_sun15.jpg
# o_ocean_coast_sun3.jpg
# o_ocean_coast_sun34.jpg
# o_ocean_coast_sun57.jpg
# o_ocean_coast_sun59.jpg
# o_ocean_coast_sun7.jpg
# r_river_coast_natu515.jpg
# s_sea_sea01.jpg
# s_sea_sea02.jpg
# s_sea_sea03.jpg
# s_sea_sea_000102.jpg
# s_sea_sea_000387.jpg
# s_sea_sea_000491.jpg
# s_sea_sea_000771.jpg
# s_seaside_seaside_000009.jpg
# s_seaside_seaside_000015.jpg
# s_seaside_seaside_000020.jpg
# s_seaside_seaside_000042.jpg
# s_seaside_seaside_000144.jpg
# s_seaside_seaside_000206.jpg
# s_seaside_seaside_000403.jpg
# s_seaside_seaside_000498.jpg
# s_seaside_seaside_000683.jpg
# s_seaside_seaside_000779.jpg
# s_seaside_seaside_000974.jpg
# Gap: 10
# Number of coast files for validation: 40
# Number of coast files for test: 40
# Number of files in coast validation: 40
# Number of files in coast test: 40
# Number of files in coast train: 325

# %%
# copy the forest files
copy_files("forest")
# Out:
# Number of files in forest dataset: 351
# b_backwater_24_19a_flooded_forest.jpg
# b_bambouserie_2983517_xitou_bamboo_forest_taiwan.jpg
# b_bambouserie_44200_bamboo_forest2.jpg
# b_bambouserie_456892_a_bamboo_forest_1.jpg
# c_country_road_forest_land222.jpg
# c_country_road_forest_land224.jpg
# f_forest_150056.jpg
# f_forest_151008.jpg
# f_forest_151051.jpg
# f_forest_266095.jpg
# f_forest_36072.jpg
# f_forest_482008.jpg
# f_forest_482082.jpg
# f_forest_50058.jpg
# f_forest_536_n_123_x4909.jpg
# f_forest_95041.jpg
# f_forest_aa048712.jpg
# f_forest_e003764.jpg
# f_forest_forest_000042.jpg
# f_forest_forest_000099.jpg
# f_forest_forest_11_20_yahoo_80.jpg
# f_forest_forest_36_05_altavista_87.jpg
# f_forest_forest_art114.jpg
# f_forest_forest_bost101.jpg
# f_forest_forest_bost102.jpg
# f_forest_forest_bost103.jpg
# f_forest_forest_bost190.jpg
# f_forest_forest_bost98.jpg
# f_forest_forest_cdmc101.jpg
# f_forest_forest_cdmc12.jpg
# f_forest_forest_cdmc271.jpg
# f_forest_forest_cdmc277.jpg
# f_forest_forest_cdmc278.jpg
# f_forest_forest_cdmc280.jpg
# f_forest_forest_cdmc281.jpg
# f_forest_forest_cdmc283.jpg
# f_forest_forest_cdmc284.jpg
# f_forest_forest_cdmc290.jpg
# f_forest_forest_cdmc291.jpg
# f_forest_forest_cdmc292.jpg
# f_forest_forest_cdmc293.jpg
# f_forest_forest_cdmc306.jpg
# f_forest_forest_cdmc313.jpg
# f_forest_forest_cdmc315.jpg
# f_forest_forest_cdmc317.jpg
# f_forest_forest_cdmc319.jpg
# f_forest_forest_cdmc331.jpg
# f_forest_forest_cdmc333.jpg
# f_forest_forest_cdmc338.jpg
# f_forest_forest_cdmc344.jpg
# f_forest_forest_cdmc348.jpg
# f_forest_forest_cdmc351.jpg
# f_forest_forest_cdmc352.jpg
# f_forest_forest_cdmc358.jpg
# f_forest_forest_cdmc359.jpg
# f_forest_forest_cdmc363.jpg
# f_forest_forest_cdmc368.jpg
# f_forest_forest_cdmc375.jpg
# f_forest_forest_cdmc377.jpg
# f_forest_forest_cdmc385.jpg
# f_forest_forest_cdmc388.jpg
# f_forest_forest_cdmc414.jpg
# f_forest_forest_cdmc415.jpg
# f_forest_forest_cdmc430.jpg
# f_forest_forest_cdmc451.jpg
# f_forest_forest_cdmc458.jpg
# f_forest_forest_cdmc494.jpg
# f_forest_forest_cdmc507.jpg
# f_forest_forest_cdmc533.jpg
# f_forest_forest_cdmc547.jpg
# f_forest_forest_cdmc556.jpg
# f_forest_forest_cdmc562.jpg
# f_forest_forest_for102.jpg
# f_forest_forest_for105.jpg
# f_forest_forest_for106.jpg
# f_forest_forest_for110.jpg
# f_forest_forest_for112.jpg
# f_forest_forest_for114.jpg
# f_forest_forest_for116.jpg
# f_forest_forest_for119.jpg
# f_forest_forest_for121.jpg
# f_forest_forest_for127.jpg
# f_forest_forest_for130.jpg
# f_forest_forest_for132.jpg
# f_forest_forest_for136.jpg
# f_forest_forest_for137.jpg
# f_forest_forest_for142.jpg
# f_forest_forest_for143.jpg
# f_forest_forest_for146.jpg
# f_forest_forest_for148.jpg
# f_forest_forest_for149.jpg
# f_forest_forest_for15.jpg
# f_forest_forest_for151.jpg
# f_forest_forest_for153.jpg
# f_forest_forest_for157.jpg
# f_forest_forest_for25.jpg
# f_forest_forest_for27.jpg
# f_forest_forest_for28.jpg
# f_forest_forest_for3.jpg
# f_forest_forest_for32.jpg
# f_forest_forest_for42.jpg
# f_forest_forest_for44.jpg
# f_forest_forest_for47.jpg
# f_forest_forest_for50.jpg
# f_forest_forest_for52.jpg
# f_forest_forest_for58.jpg
# f_forest_forest_for60.jpg
# f_forest_forest_for65.jpg
# f_forest_forest_for78.jpg
# f_forest_forest_for79.jpg
# f_forest_forest_for82.jpg
# f_forest_forest_for84.jpg
# f_forest_forest_for85.jpg
# f_forest_forest_for86.jpg
# f_forest_forest_for87.jpg
# f_forest_forest_for93.jpg
# f_forest_forest_for96.jpg
# f_forest_forest_land102.jpg
# f_forest_forest_land107.jpg
# f_forest_forest_land159.jpg
# f_forest_forest_land215.jpg
# f_forest_forest_land217.jpg
# f_forest_forest_land243.jpg
# f_forest_forest_land314.jpg
# f_forest_forest_land335.jpg
# f_forest_forest_land503.jpg
# f_forest_forest_land64.jpg
# f_forest_forest_land726.jpg
# f_forest_forest_land727.jpg
# f_forest_forest_land733.jpg
# f_forest_forest_land801.jpg
# f_forest_forest_land807.jpg
# f_forest_forest_land849.jpg
# f_forest_forest_land850.jpg
# f_forest_forest_land852.jpg
# f_forest_forest_land854.jpg
# f_forest_forest_land858.jpg
# f_forest_forest_land862.jpg
# f_forest_forest_land863.jpg
# f_forest_forest_land864.jpg
# f_forest_forest_land866.jpg
# f_forest_forest_land867.jpg
# f_forest_forest_land869.jpg
# f_forest_forest_land870.jpg
# f_forest_forest_land871.jpg
# f_forest_forest_land872.jpg
# f_forest_forest_land873.jpg
# f_forest_forest_n18075.jpg
# f_forest_forest_nat1033.jpg
# f_forest_forest_nat1184.jpg
# f_forest_forest_nat1217.jpg
# f_forest_forest_nat1242.jpg
# f_forest_forest_nat1248.jpg
# f_forest_forest_nat130.jpg
# f_forest_forest_nat145.jpg
# f_forest_forest_nat146.jpg
# f_forest_forest_nat147.jpg
# f_forest_forest_nat162.jpg
# f_forest_forest_nat203.jpg
# f_forest_forest_nat204.jpg
# f_forest_forest_nat205.jpg
# f_forest_forest_nat208.jpg
# f_forest_forest_nat209.jpg
# f_forest_forest_nat210.jpg
# f_forest_forest_nat211.jpg
# f_forest_forest_nat219.jpg
# f_forest_forest_nat220.jpg
# f_forest_forest_nat221.jpg
# f_forest_forest_nat315.jpg
# f_forest_forest_nat324.jpg
# f_forest_forest_nat325.jpg
# f_forest_forest_nat328.jpg
# f_forest_forest_nat337.jpg
# f_forest_forest_nat338.jpg
# f_forest_forest_nat347.jpg
# f_forest_forest_nat349.jpg
# f_forest_forest_nat354.jpg
# f_forest_forest_nat359.jpg
# f_forest_forest_nat360.jpg
# f_forest_forest_nat361.jpg
# f_forest_forest_nat367.jpg
# f_forest_forest_nat373.jpg
# f_forest_forest_nat398.jpg
# f_forest_forest_nat400.jpg
# f_forest_forest_nat417.jpg
# f_forest_forest_nat442.jpg
# f_forest_forest_nat449.jpg
# f_forest_forest_nat450.jpg
# f_forest_forest_nat451.jpg
# f_forest_forest_nat452.jpg
# f_forest_forest_nat468.jpg
# f_forest_forest_nat470.jpg
# f_forest_forest_nat619.jpg
# f_forest_forest_nat623.jpg
# f_forest_forest_nat697.jpg
# f_forest_forest_nat715.jpg
# f_forest_forest_nat719.jpg
# f_forest_forest_nat763.jpg
# f_forest_forest_nat798.jpg
# f_forest_forest_nat835.jpg
# f_forest_forest_nat851.jpg
# f_forest_forest_nat867.jpg
# f_forest_forest_nat946.jpg
# f_forest_forest_nat982.jpg
# f_forest_forest_natc12.jpg
# f_forest_forest_natc37.jpg
# f_forest_forest_natc49.jpg
# f_forest_forest_natu15.jpg
# f_forest_forest_natu163.jpg
# f_forest_forest_natu164.jpg
# f_forest_forest_natu18.jpg
# f_forest_forest_natu2.jpg
# f_forest_forest_natu26.jpg
# f_forest_forest_natu28.jpg
# f_forest_forest_natu29.jpg
# f_forest_forest_natu308.jpg
# f_forest_forest_natu317.jpg
# f_forest_forest_natu322.jpg
# f_forest_forest_natu361.jpg
# f_forest_forest_natu396.jpg
# f_forest_forest_natu402.jpg
# f_forest_forest_natu423.jpg
# f_forest_forest_natu424.jpg
# f_forest_forest_natu425.jpg
# f_forest_forest_natu428.jpg
# f_forest_forest_natu430.jpg
# f_forest_forest_natu439.jpg
# f_forest_forest_natu440.jpg
# f_forest_forest_natu441.jpg
# f_forest_forest_natu443.jpg
# f_forest_forest_natu611.jpg
# f_forest_forest_natu634.jpg
# f_forest_forest_natu696.jpg
# f_forest_forest_natu707.jpg
# f_forest_forest_natu72.jpg
# f_forest_forest_natu794.jpg
# f_forest_forest_natu846.jpg
# f_forest_forest_natu847.jpg
# f_forest_forest_natu848.jpg
# f_forest_forest_natu850.jpg
# f_forest_forest_natu863.jpg
# f_forest_forest_natu866.jpg
# f_forest_forest_natu869.jpg
# f_forest_forest_natu870.jpg
# f_forest_forest_natu871.jpg
# f_forest_forest_natu895.jpg
# f_forest_forest_natu898.jpg
# f_forest_forest_natu913.jpg
# f_forest_forest_natu934.jpg
# f_forest_forest_natu949.jpg
# f_forest_forest_natu977.jpg
# f_forest_forest_natu994.jpg
# f_forest_forest_tell51.jpg
# f_forest_forest_text103.jpg
# f_forest_forest_text105.jpg
# f_forest_forest_text106.jpg
# f_forest_forest_text107.jpg
# f_forest_forest_text11.jpg
# f_forest_forest_text119.jpg
# f_forest_forest_text122.jpg
# f_forest_forest_text124.jpg
# f_forest_forest_text20.jpg
# f_forest_forest_text26.jpg
# f_forest_forest_text29.jpg
# f_forest_forest_text35.jpg
# f_forest_forest_text40.jpg
# f_forest_forest_text41.jpg
# f_forest_forest_text42.jpg
# f_forest_forest_text43.jpg
# f_forest_forest_text44.jpg
# f_forest_forest_text45.jpg
# f_forest_forest_text46.jpg
# f_forest_forest_text47.jpg
# f_forest_forest_text48.jpg
# f_forest_forest_text49.jpg
# f_forest_forest_text50.jpg
# f_forest_forest_text90.jpg
# f_forest_forest_urb753.jpg
# f_forest_freefoto_forest_3_20_39.jpg
# f_forest_na000139.jpg
# f_forest_na000900.jpg
# f_forest_na001279.jpg
# f_forest_na001393.jpg
# f_forest_na007023.jpg
# f_forest_na007264.jpg
# f_forest_na008642.jpg
# f_forest_nbe_001.jpg
# f_forest_path_86026.jpg
# f_forest_path_aa022849.jpg
# f_forest_path_aa027527.jpg
# f_forest_path_cdmc318.jpg
# f_forest_path_coast_n291032.jpg
# f_forest_path_difficult04_267.jpg
# f_forest_path_forest_cdmc318.jpg
# f_forest_path_forest_for77.jpg
# f_forest_path_forest_land219.jpg
# f_forest_path_forest_land245.jpg
# f_forest_path_forest_land861.jpg
# f_forest_path_forest_nat1027.jpg
# f_forest_path_forest_nat1097.jpg
# f_forest_path_forest_nat1253.jpg
# f_forest_path_forest_nat223.jpg
# f_forest_path_forest_nat310.jpg
# f_forest_path_forest_natu325.jpg
# f_forest_path_google_36_11_1_forest_path.jpg
# f_forest_path_google_5_8_3_forest_path.jpg
# f_forest_path_lane_000005.jpg
# f_forest_path_na003469.jpg
# f_forest_path_na005419.jpg
# f_forest_path_na008428.jpg
# f_forest_path_nla_082.jpg
# f_forest_path_nortontrailstartsouth_3_17_01_140.jpg
# f_forest_path_path183_355.jpg
# f_forest_path_path_000363.jpg
# f_forest_path_path_to_beach_331.jpg
# f_forest_path_sip2001416_p_173.jpg
# f_forest_path_tr000937.jpg
# f_forest_path_tr007191.jpg
# f_forest_path_trail_head_000006.jpg
# h_hill_forest_nat239.jpg
# l_lake_forest_text13.jpg
# l_lake_forest_text28.jpg
# m_mountain_snowy_forest_land922.jpg
# m_mountain_snowy_forest_nat212.jpg
# p_park_forest_cdmc282.jpg
# p_park_forest_land81.jpg
# r_rainforest_google_13_18_3_rainforest.jpg
# r_rainforest_google_17_4_1_rainforest.jpg
# r_rainforest_google_40_15_1_rainforest.jpg
# r_rainforest_rain_forest_000108.jpg
# r_rainforest_rain_forest_000334.jpg
# r_rainforest_rain_forest_000426.jpg
# r_rainforest_rain_forest_000578.jpg
# r_rainforest_rain_forest_000620.jpg
# r_rainforest_temperate_rain_forest_000053.jpg
# r_rainforest_temperate_rain_forest_000127.jpg
# r_rainforest_tropical_rain_forest_000042.jpg
# r_river_forest_bost100.jpg
# r_river_forest_for17.jpg
# r_river_forest_for20.jpg
# r_river_forest_for22.jpg
# r_river_forest_for38.jpg
# r_river_forest_for63.jpg
# r_river_forest_for67.jpg
# r_river_forest_for95.jpg
# r_river_forest_land741.jpg
# r_river_forest_land810.jpg
# r_river_forest_nat717.jpg
# r_river_forest_natu169.jpg
# r_river_forest_natu170.jpg
# r_river_forest_sclos11.jpg
# Gap: 10
# Number of forest files for validation: 35
# Number of forest files for test: 35
# Number of files in forest validation: 35
# Number of files in forest test: 35
# Number of files in forest train: 281

# %%
copy_files("mountain")
# Out:
# Number of files in mountain dataset: 402
# c_canyon_mountain_land4.jpg
# c_canyon_mountain_sharp22.jpg
# c_country_road_mountain_land225.jpg
# m_mountain_142053.jpg
# m_mountain_19083.jpg
# m_mountain_38038.jpg
# m_mountain_38041.jpg
# m_mountain_671080.jpg
# m_mountain_mountain_gre242.jpg
# m_mountain_mountain_land11.jpg
# m_mountain_mountain_land131.jpg
# m_mountain_mountain_land150.jpg
# m_mountain_mountain_land153.jpg
# m_mountain_mountain_land197.jpg
# m_mountain_mountain_land198.jpg
# m_mountain_mountain_land201.jpg
# m_mountain_mountain_land260.jpg
# m_mountain_mountain_land27.jpg
# m_mountain_mountain_land278.jpg
# m_mountain_mountain_land280.jpg
# m_mountain_mountain_land281.jpg
# m_mountain_mountain_land286.jpg
# m_mountain_mountain_land30.jpg
# m_mountain_mountain_land465.jpg
# m_mountain_mountain_land471.jpg
# m_mountain_mountain_land475.jpg
# m_mountain_mountain_land644.jpg
# m_mountain_mountain_land879.jpg
# m_mountain_mountain_land880.jpg
# m_mountain_mountain_land886.jpg
# m_mountain_mountain_land917.jpg
# m_mountain_mountain_moun1.jpg
# m_mountain_mountain_moun10.jpg
# m_mountain_mountain_moun13.jpg
# m_mountain_mountain_moun14.jpg
# m_mountain_mountain_moun27.jpg
# m_mountain_mountain_moun32.jpg
# m_mountain_mountain_moun37.jpg
# m_mountain_mountain_moun38.jpg
# m_mountain_mountain_moun41.jpg
# m_mountain_mountain_moun44.jpg
# m_mountain_mountain_n18009.jpg
# m_mountain_mountain_n18024.jpg
# m_mountain_mountain_n18036.jpg
# m_mountain_mountain_n18039.jpg
# m_mountain_mountain_n18044.jpg
# m_mountain_mountain_n18058.jpg
# m_mountain_mountain_n199015.jpg
# m_mountain_mountain_n199073.jpg
# m_mountain_mountain_n199074.jpg
# m_mountain_mountain_n199075.jpg
# m_mountain_mountain_n199080.jpg
# m_mountain_mountain_n213085.jpg
# m_mountain_mountain_n219006.jpg
# m_mountain_mountain_n251048.jpg
# m_mountain_mountain_n255008.jpg
# m_mountain_mountain_n255068.jpg
# m_mountain_mountain_n295018.jpg
# m_mountain_mountain_n295042.jpg
# m_mountain_mountain_n295082.jpg
# m_mountain_mountain_n344019.jpg
# m_mountain_mountain_n344028.jpg
# m_mountain_mountain_n344032.jpg
# m_mountain_mountain_n344047.jpg
# m_mountain_mountain_n344053.jpg
# m_mountain_mountain_n344082.jpg
# m_mountain_mountain_n347051.jpg
# m_mountain_mountain_n347077.jpg
# m_mountain_mountain_n347078.jpg
# m_mountain_mountain_n371063.jpg
# m_mountain_mountain_n371071.jpg
# m_mountain_mountain_n371076.jpg
# m_mountain_mountain_n392087.jpg
# m_mountain_mountain_n392090.jpg
# m_mountain_mountain_n405000.jpg
# m_mountain_mountain_n405023.jpg
# m_mountain_mountain_n405030.jpg
# m_mountain_mountain_n44031.jpg
# m_mountain_mountain_n480098.jpg
# m_mountain_mountain_n510071.jpg
# m_mountain_mountain_n603048.jpg
# m_mountain_mountain_n632073.jpg
# m_mountain_mountain_n736023.jpg
# m_mountain_mountain_n736026.jpg
# m_mountain_mountain_n736029.jpg
# m_mountain_mountain_n737049.jpg
# m_mountain_mountain_n860034.jpg
# m_mountain_mountain_nat1142.jpg
# m_mountain_mountain_nat199.jpg
# m_mountain_mountain_nat316.jpg
# m_mountain_mountain_nat317.jpg
# m_mountain_mountain_nat332.jpg
# m_mountain_mountain_nat340.jpg
# m_mountain_mountain_nat346.jpg
# m_mountain_mountain_nat391.jpg
# m_mountain_mountain_nat481.jpg
# m_mountain_mountain_nat55.jpg
# m_mountain_mountain_nat758.jpg
# m_mountain_mountain_nat79.jpg
# m_mountain_mountain_nat80.jpg
# m_mountain_mountain_nat801.jpg
# m_mountain_mountain_nat84.jpg
# m_mountain_mountain_nat87.jpg
# m_mountain_mountain_nat876.jpg
# m_mountain_mountain_nat93.jpg
# m_mountain_mountain_natu568.jpg
# m_mountain_mountain_natu687.jpg
# m_mountain_mountain_natu697.jpg
# m_mountain_mountain_sharp21.jpg
# m_mountain_mountain_sharp29.jpg
# m_mountain_mountain_sharp46.jpg
# m_mountain_mountain_sharp61.jpg
# m_mountain_mountain_sharp67.jpg
# m_mountain_mountain_sharp70.jpg
# m_mountain_mountain_sharp78.jpg
# m_mountain_na008577.jpg
# m_mountain_opencountry_nat355.jpg
# m_mountain_peak_mountain_peak_000123.jpg
# m_mountain_snowy_18019.jpg
# m_mountain_snowy_18067.jpg
# m_mountain_snowy_380019.jpg
# m_mountain_snowy_38063.jpg
# m_mountain_snowy_38067.jpg
# m_mountain_snowy_44010.jpg
# m_mountain_snowy_697007.jpg
# m_mountain_snowy_aa002394.jpg
# m_mountain_snowy_aa005528.jpg
# m_mountain_snowy_mountain51_91.jpg
# m_mountain_snowy_mountain62_102.jpg
# m_mountain_snowy_mountain_art1131.jpg
# m_mountain_snowy_mountain_art1132.jpg
# m_mountain_snowy_mountain_cdmc181.jpg
# m_mountain_snowy_mountain_cdmc184.jpg
# m_mountain_snowy_mountain_land10.jpg
# m_mountain_snowy_mountain_land130.jpg
# m_mountain_snowy_mountain_land132.jpg
# m_mountain_snowy_mountain_land142.jpg
# m_mountain_snowy_mountain_land143.jpg
# m_mountain_snowy_mountain_land145.jpg
# m_mountain_snowy_mountain_land15.jpg
# m_mountain_snowy_mountain_land16.jpg
# m_mountain_snowy_mountain_sharp12.jpg
# m_mountain_snowy_mountain_sharp13.jpg
# m_mountain_snowy_mountain_sharp16.jpg
# m_mountain_snowy_mountain_sharp18.jpg
# m_mountain_snowy_mountain_sharp19.jpg
# m_mountain_snowy_mountain_sharp20.jpg
# m_mountain_snowy_mountain_sharp27.jpg
# m_mountain_snowy_mountain_sharp32.jpg
# m_mountain_snowy_mountain_sharp33.jpg
# m_mountain_snowy_mountain_sharp34.jpg
# m_mountain_snowy_mountain_sharp38.jpg
# m_mountain_snowy_mountain_sharp40.jpg
# m_mountain_snowy_mountain_sharp41.jpg
# m_mountain_snowy_mountain_sharp42.jpg
# m_mountain_snowy_mountain_sharp43.jpg
# m_mountain_snowy_mountain_sharp44.jpg
# m_mountain_snowy_mountain_sharp45.jpg
# m_mountain_snowy_mountain_sharp47.jpg
# m_mountain_snowy_mountain_sharp48.jpg
# m_mountain_snowy_mountain_sharp5.jpg
# m_mountain_snowy_mountain_sharp52.jpg
# m_mountain_snowy_mountain_sharp53.jpg
# m_mountain_snowy_mountain_sharp54.jpg
# m_mountain_snowy_mountain_sharp59.jpg
# m_mountain_snowy_mountain_sharp60.jpg
# m_mountain_snowy_mountain_sharp63.jpg
# m_mountain_snowy_mountain_sharp66.jpg
# m_mountain_snowy_mountain_sharp68.jpg
# m_mountain_snowy_mountain_sharp69.jpg
# m_mountain_snowy_mountain_sharp71.jpg
# m_mountain_snowy_mountain_sharp72.jpg
# m_mountain_snowy_mountain_sharp73.jpg
# m_mountain_snowy_mountain_sharp74.jpg
# m_mountain_snowy_mountain_sharp91.jpg
# m_mountain_snowy_mountain_sharp92.jpg
# m_mountain_snowy_mountain_sharp96.jpg
# m_mountain_snowy_mountain_sharp98.jpg
# m_mountain_snowy_mountain_ski24.jpg
# m_mountain_snowy_mountain_ski5.jpg
# m_mountain_snowy_mountain_ski57.jpg
# m_mountain_snowy_mountain_ski61.jpg
# m_mountain_snowy_mountain_ski62.jpg
# m_mountain_snowy_mountain_ski65.jpg
# m_mountain_snowy_mountain_ski69.jpg
# m_mountain_snowy_mountain_ski72.jpg
# m_mountain_snowy_mountain_sopen16.jpg
# m_mountain_snowy_mountain_sopen24.jpg
# m_mountain_snowy_na000418.jpg
# m_mountain_snowy_na000430.jpg
# m_mountain_snowy_na001472.jpg
# m_mountain_snowy_na001539.jpg
# m_mountain_snowy_na006859.jpg
# m_mountain_snowy_nat692_268.jpg
# m_mountain_snowy_nat783_278.jpg
# m_mountain_snowy_nbe_028.jpg
# m_mountain_snowy_opencountry_nat1010.jpg
# m_mountain_tent_mountain_tent_000020.jpg
# m_mountain_trail_mountain_trail_000047.jpg
# m_mountain_trail_mountain_trail_000142.jpg
# m_mountain_wl000020.jpg
# Gap: 10
# Number of mountain files for validation: 40
# Number of mountain files for test: 40
# Number of files in mountain validation: 40
# Number of files in mountain test: 40
# Number of files in mountain train: 322

# %%
325+40+40
# Out:
# 405

# %%
281+35+35
# Out:
# 351

# %%
322+40+40
# Out:
# 402
